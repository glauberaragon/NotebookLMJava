# %% [markdown]
# <a href="https://colab.research.google.com/github/glauberaragon/NotebookLMJava/blob/main/TESTE_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World!")
# Out:
# Hello World!

# %%
print ("Olá, Mundo!")
# Out:
# Olá, Mundo!

# %%
# Definir variáveis
# Usamos int() para transformar o texto do input em número inteiro
var1 = int(input("Digite o primeiro número: "))
var2 = int(input("Digite o segundo número: "))
var3 = 15

soma_das_duas_variáveis = var1 + var2

if soma_das_duas_variáveis > var3:
    print("Acertou Miserávi")
else:
    print(f"erroooou! A soma deu {soma_das_duas_variáveis}")
# Out:
# Digite o primeiro número: 6
# Digite o segundo número: 10
# Acertou Miserávi
